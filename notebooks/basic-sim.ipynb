# %%
import importlib
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import npeb
from npeb.GLMixture import GLMixture
import itertools
from scipy.linalg import sqrtm, inv
from scipy.spatial import distance_matrix
import ot

# %% [markdown]
# ## Data Generation

# %%
n = 2500
center1 = np.asarray([0.5, 0.5])
center2 = np.asarray([-0.5, -0.5])
tau2 = 0.1
sigma2 = 1.0

np.random.seed(54321)

# %%
centers = np.vstack([center1, center2])

def sample_latent(nsamples, var):
  classes = np.random.randint(0, 2, size = nsamples)
  indices = np.zeros((nsamples, 2))
  indices[np.arange(nsamples), classes] = 1
  Theta = np.random.normal(indices@centers, np.sqrt(var))
  return Theta

# %%
Theta = sample_latent(n, tau2)
prec = np.ones_like(Theta)/sigma2
prec_smooth = 1./(1./prec + tau2)
Z = np.random.normal(Theta, np.sqrt(sigma2), size = (n, 2))
L = np.max(Z)

# %% [markdown]
# ## Compute denoisers

# %% [markdown]
# ### Oracle Bayes

# %%
ob_model = GLMixture(prec_type='diagonal')
n_supp = 400 # number of (empirical) support points to have for the oracle prior
supp = sample_latent(n_supp,tau2) # this defines the (empirical) (oracle) prior support 
ob_model.set_params(atoms=supp, weights=np.ones(n_supp)/n_supp)
ob_means = ob_model.posterior_mean(Z, prec)
ob_indices, ob_samples = ob_model.posterior_sample(Z, prec, n_samples=2500)

# %% [markdown]
# ### Empirical Bayes

# %% [markdown]
# First, we do empirical Bayes denoising with `prec_smooth`. Using `prec_smooth` pools the variances of $Z \mid \Theta$ and $\Theta \mid \mu$, and hence tries to estimate $H$, the prior/mixing measure for $\mu$, which are the cluster means. In the original data, the mixing measure places equal weight on the two possible values of $\mu$, which are $(0.5, 0.5)$ and $(-0.5, -0.5)$.

# %%
L = 1
atoms_init = np.meshgrid(np.linspace(-L, L, 20), np.linspace(-L, L, 20))
atoms_init = np.vstack([a.flatten() for a in atoms_init]).T

# %%
eb_model_h = GLMixture(prec_type='diagonal', atoms_init=atoms_init)
eb_model_h.fit(Z, prec_smooth)
# Out:
# (CVXPY) Jan 25 01:15:20 AM: Your problem has 400 variables, 401 constraints, and 0 parameters.
# (CVXPY) Jan 25 01:15:20 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jan 25 01:15:20 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jan 25 01:15:20 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jan 25 01:15:20 AM: Your problem is compiled with the CPP canonicalization backend.
# (CVXPY) Jan 25 01:15:20 AM: Compiling problem (target solver=MOSEK).
# (CVXPY) Jan 25 01:15:20 AM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Jan 25 01:15:20 AM: Applying reduction FlipObjective
# (CVXPY) Jan 25 01:15:20 AM: Applying reduction Dcp2Cone
# (CVXPY) Jan 25 01:15:20 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 25 01:15:20 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jan 25 01:15:20 AM: Applying reduction MOSEK
# Computing kernel matrix: done.
# Solving for discretized NPMLE: ===============================================================================
#                                      CVXPY
#                                      v1.7.5
# ===============================================================================
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jan 25 01:15:20 AM: Finished problem compilation (took 1.963e-01 seconds).
# (CVXPY) Jan 25 01:15:20 AM: Invoking solver MOSEK  to obtain a solution.
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jan 25 01:15:21 AM: Problem
# (CVXPY) Jan 25 01:15:21 AM:   Name                   :
# (CVXPY) Jan 25 01:15:21 AM:   Objective sense        : maximize
# (CVXPY) Jan 25 01:15:21 AM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Jan 25 01:15:21 AM:   Constraints            : 2900
# (CVXPY) Jan 25 01:15:21 AM:   Affine conic cons.     : 0
# (CVXPY) Jan 25 01:15:21 AM:   Disjunctive cons.      : 0
# (CVXPY) Jan 25 01:15:21 AM:   Cones                  : 2500
# (CVXPY) Jan 25 01:15:21 AM:   Scalar variables       : 7901
# (CVXPY) Jan 25 01:15:21 AM:   Matrix variables       : 0
# (CVXPY) Jan 25 01:15:21 AM:   Integer variables      : 0
# (CVXPY) Jan 25 01:15:21 AM:
# (CVXPY) Jan 25 01:15:21 AM: Optimizer started.
# (CVXPY) Jan 25 01:15:21 AM: Presolve started.
# (CVXPY) Jan 25 01:15:21 AM: Linear dependency checker started.
# (CVXPY) Jan 25 01:15:21 AM: Linear dependency checker terminated.
# (CVXPY) Jan 25 01:15:21 AM: Eliminator started.
# (CVXPY) Jan 25 01:15:21 AM: Freed constraints in eliminator : 0
# (CVXPY) Jan 25 01:15:21 AM: Eliminator terminated.
# (CVXPY) Jan 25 01:15:21 AM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Jan 25 01:15:21 AM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Jan 25 01:15:21 AM: Lin. dep.  - primal attempts        : 1                 successes              : 1
# (CVXPY) Jan 25 01:15:21 AM: Lin. dep.  - dual attempts          : 0                 successes              : 0
# (CVXPY) Jan 25 01:15:21 AM: Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# (CVXPY) Jan 25 01:15:21 AM: Presolve terminated. Time: 0.03
# (CVXPY) Jan 25 01:15:21 AM: Optimizer  - threads                : 10
# (CVXPY) Jan 25 01:15:21 AM: Optimizer  - solved problem         : the primal
# (CVXPY) Jan 25 01:15:21 AM: Optimizer  - Constraints            : 400
# (CVXPY) Jan 25 01:15:21 AM: Optimizer  - Cones                  : 2501
# (CVXPY) Jan 25 01:15:21 AM: Optimizer  - Scalar variables       : 7902              conic                  : 7502
# (CVXPY) Jan 25 01:15:21 AM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Jan 25 01:15:21 AM: Factor     - setup time             : 0.12
# (CVXPY) Jan 25 01:15:21 AM: Factor     - dense det. time        : 0.01              GP order time          : 0.00
# (CVXPY) Jan 25 01:15:21 AM: Factor     - nonzeros before factor : 8.02e+04          after factor           : 8.02e+04
# (CVXPY) Jan 25 01:15:21 AM: Factor     - dense dim.             : 0                 flops                  : 8.24e+08
# (CVXPY) Jan 25 01:15:21 AM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Jan 25 01:15:21 AM: 0   7.6e+01  1.3e+00  4.1e+03  0.00e+00   -2.069595998e+03  2.012755004e+03   1.0e+00  0.25
# (CVXPY) Jan 25 01:15:21 AM: 1   4.2e+01  7.2e-01  2.1e+03  2.28e-01   -1.457149239e+03  1.518687141e+03   5.6e-01  0.27
# (CVXPY) Jan 25 01:15:21 AM: 2   2.2e+01  3.8e-01  1.0e+03  2.35e-01   -3.082195778e+02  1.780712340e+03   3.0e-01  0.29
# (CVXPY) Jan 25 01:15:21 AM: 3   6.2e+00  1.1e-01  2.5e+02  2.20e-01   1.628511846e+03   2.555582124e+03   8.2e-02  0.30
# (CVXPY) Jan 25 01:15:21 AM: 4   9.3e-01  1.6e-02  3.2e+01  1.88e-01   3.794259555e+03   4.047751052e+03   1.2e-02  0.32
# (CVXPY) Jan 25 01:15:21 AM: 5   1.4e-01  2.4e-03  4.7e+00  1.09e-01   5.548153147e+03   5.627110292e+03   1.9e-03  0.33
# (CVXPY) Jan 25 01:15:21 AM: 6   4.7e-02  8.0e-04  1.5e+00  1.14e-01   6.457302559e+03   6.503033926e+03   6.2e-04  0.35
# (CVXPY) Jan 25 01:15:21 AM: 7   1.4e-02  2.4e-04  3.7e-01  2.76e-01   7.128216012e+03   7.148523822e+03   1.9e-04  0.36
# (CVXPY) Jan 25 01:15:21 AM: 27  5.3e-09  5.4e-11  6.1e-11  1.00e+00   7.786444832e+03   7.786444842e+03   4.2e-11  0.69
# (CVXPY) Jan 25 01:15:21 AM: 28  5.3e-09  5.4e-11  6.1e-11  1.00e+00   7.786444832e+03   7.786444842e+03   4.2e-11  0.74
# (CVXPY) Jan 25 01:15:21 AM: 29  4.8e-09  5.1e-11  5.6e-11  9.99e-01   7.786444852e+03   7.786444861e+03   3.9e-11  0.78
# (CVXPY) Jan 25 01:15:21 AM: 30  1.6e-09  3.7e-12  1.1e-12  9.95e-01   7.786445160e+03   7.786445161e+03   2.9e-12  0.81
# (CVXPY) Jan 25 01:15:22 AM: 31  1.6e-09  3.7e-12  1.1e-12  1.00e+00   7.786445160e+03   7.786445161e+03   2.9e-12  0.86
# (CVXPY) Jan 25 01:15:22 AM: 32  1.4e-09  3.7e-12  1.1e-12  1.00e+00   7.786445160e+03   7.786445161e+03   2.9e-12  0.90
# (CVXPY) Jan 25 01:15:22 AM: Optimizer terminated. Time: 0.96
# (CVXPY) Jan 25 01:15:22 AM:
# (CVXPY) Jan 25 01:15:22 AM:
# (CVXPY) Jan 25 01:15:22 AM: Interior-point solution summary
# (CVXPY) Jan 25 01:15:22 AM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Jan 25 01:15:22 AM:   Solution status : OPTIMAL
# (CVXPY) Jan 25 01:15:22 AM:   Primal.  obj: 7.7864451599e+03    nrm: 6e+03    Viol.  con: 8e-08    var: 0e+00    cones: 0e+00
# (CVXPY) Jan 25 01:15:22 AM:   Dual.    obj: 7.7864451606e+03    nrm: 9e+00    Viol.  con: 0e+00    var: 6e-10    cones: 0e+00
# (CVXPY) Jan 25 01:15:22 AM: Problem status: optimal
# (CVXPY) Jan 25 01:15:22 AM: Optimal value: -7.786e+03
# (CVXPY) Jan 25 01:15:22 AM: Compilation took 1.963e-01 seconds
# (CVXPY) Jan 25 01:15:22 AM: Solver (including time spent in interface) took 1.217e+00 seconds
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# done.
# Running EM: done.
# [np.float64(-3.1145780749164116),
#  np.float64(-3.1145740801470185),
#  np.float64(-3.1145706889737994),
#  np.float64(-3.1145677355509807),
#  np.float64(-3.114565143154334),
#  np.float64(-3.114562857623509),
#  np.float64(-3.1145608365725703),
#  np.float64(-3.114559044971996),
#  np.float64(-3.1145574530971194),
#  np.float64(-3.1145560354092914),
#  np.float64(-3.1145547698361153)]

# %% [markdown]
# Using the estimated prior $\hat{H}$ of $\mu$, we wish to find the estimated prior $\hat{G}(\hat{H})$ of $\Theta$. To plot this estimated prior, we will draw samples of $\mu$ according to their estimated _prior_ weights and then add $\mathcal{N}(0, \tau^2)$ noise.

# %%
h_hat_supp = eb_model_h.atoms
h_hat_weights = eb_model_h.weights
# sample n = 2500 points from h_hat_supp with weights h_hat_weights and then add gaussian noise of tau^2 to get (discrete) estimated prior.
n = 10000
g_hat_samples = np.zeros((n, 2))
for i in range(n):
    idx = np.random.choice(len(h_hat_supp), p=h_hat_weights)
    h_hat_sample = h_hat_supp[idx]
    g_hat_samples[i] = h_hat_sample + np.random.normal(0, np.sqrt(tau2), size=2)

# %% [markdown]
# Now, we want to draw samples from the posterior of $\Theta$ using linear shrinkage between the posterior for $\mu$ and the samples $Z$. We draw $\mu$ from the posterior given $Z$ or use the posterior mean for $\mu$ (resp.). For the second, we can directly plug in the posterior mean for $\mu$ by combining like terms. To draw from the mixture posterior, we use sampling with replacement over the $Z_i$. We first sample a $Z_i$, for which we then sample $\mu_i$ from the posterior of $\mu_i \mid Z_i$, and then perform the linear shrinkage using the $Z_i$, which gives us the posterior mean for $\Theta_i$. We then add the appropriate ($\sigma^2\tau^2 / (\sigma^2 + \tau^2))$ Gaussian noise.

# %%
eb_indices_h, h_samples = eb_model_h.posterior_sample(Z, prec_smooth, n_samples=10000)
eb_means_h = eb_model_h.posterior_mean(Z, prec_smooth)
post_theta_means = eb_means_h * sigma2 / (sigma2 + tau2) + Z * tau2 / (sigma2 + tau2)
post_theta_samples = h_samples * sigma2 / (sigma2 + tau2) + Z[eb_indices_h, :] * tau2 / (sigma2 + tau2) + np.random.normal(0, np.sqrt((sigma2 * tau2) / (sigma2 + tau2)), size=h_samples.shape)

# %% [markdown]
# Now, we wish to estimate the prior $G$ for $\Theta$ directly, which we do by using `prec` instead of `prec_smooth`. This does not work so well: NPMLE favors discrete and small support, soe the estimated prior $\hat{G}$ looks like the estimated prior for $\hat{H}$. Therefore, the empirical Bayes denoisers have overshrunk mean and samples from the mixture posterior are concentrated on the small estimated support.

# %%
L = np.max(np.abs(Z))
atoms_init = np.meshgrid(np.linspace(-L, L, 20), np.linspace(-L, L, 20))
atoms_init = np.vstack([a.flatten() for a in atoms_init]).T

eb_model_g = GLMixture(prec_type='diagonal', atoms_init=atoms_init)
eb_model_g.fit(Z, prec, row_condition=True, max_iter_em=10)
est_prior_weights_g, g_samples = eb_model_g.posterior_sample(Z, prec, n_samples=10000)
eb_means_g = eb_model_g.posterior_mean(Z, prec)
# Out:
# (CVXPY) Jan 27 02:42:21 PM: Your problem has 400 variables, 401 constraints, and 0 parameters.
# (CVXPY) Jan 27 02:42:21 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jan 27 02:42:21 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jan 27 02:42:21 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jan 27 02:42:21 PM: Your problem is compiled with the CPP canonicalization backend.
# (CVXPY) Jan 27 02:42:21 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Jan 27 02:42:21 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Jan 27 02:42:21 PM: Applying reduction FlipObjective
# (CVXPY) Jan 27 02:42:21 PM: Applying reduction Dcp2Cone
# (CVXPY) Jan 27 02:42:21 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 27 02:42:21 PM: Applying reduction ConeMatrixStuffing
# Computing kernel matrix: done.
# Solving for discretized NPMLE: ===============================================================================
#                                      CVXPY
#                                      v1.7.5
# ===============================================================================
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jan 27 02:42:21 PM: Applying reduction MOSEK
# (CVXPY) Jan 27 02:42:21 PM: Finished problem compilation (took 2.701e-01 seconds).
# (CVXPY) Jan 27 02:42:21 PM: Invoking solver MOSEK  to obtain a solution.
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jan 27 02:42:22 PM: Problem
# (CVXPY) Jan 27 02:42:22 PM:   Name                   :
# (CVXPY) Jan 27 02:42:22 PM:   Objective sense        : maximize
# (CVXPY) Jan 27 02:42:22 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Jan 27 02:42:22 PM:   Constraints            : 2900
# (CVXPY) Jan 27 02:42:22 PM:   Affine conic cons.     : 0
# (CVXPY) Jan 27 02:42:22 PM:   Disjunctive cons.      : 0
# (CVXPY) Jan 27 02:42:22 PM:   Cones                  : 2500
# (CVXPY) Jan 27 02:42:22 PM:   Scalar variables       : 7901
# (CVXPY) Jan 27 02:42:22 PM:   Matrix variables       : 0
# (CVXPY) Jan 27 02:42:22 PM:   Integer variables      : 0
# (CVXPY) Jan 27 02:42:22 PM:
# (CVXPY) Jan 27 02:42:22 PM: Optimizer started.
# (CVXPY) Jan 27 02:42:22 PM: Presolve started.
# (CVXPY) Jan 27 02:42:22 PM: Linear dependency checker started.
# (CVXPY) Jan 27 02:42:22 PM: Linear dependency checker terminated.
# (CVXPY) Jan 27 02:42:22 PM: Eliminator started.
# (CVXPY) Jan 27 02:42:22 PM: Freed constraints in eliminator : 0
# (CVXPY) Jan 27 02:42:22 PM: Eliminator terminated.
# (CVXPY) Jan 27 02:42:22 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Jan 27 02:42:22 PM: Lin. dep.  - tries                  : 1                 time                   : 0.01
# (CVXPY) Jan 27 02:42:22 PM: Lin. dep.  - primal attempts        : 1                 successes              : 1
# (CVXPY) Jan 27 02:42:22 PM: Lin. dep.  - dual attempts          : 0                 successes              : 0
# (CVXPY) Jan 27 02:42:22 PM: Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# (CVXPY) Jan 27 02:42:22 PM: Presolve terminated. Time: 0.25
# (CVXPY) Jan 27 02:42:23 PM: Optimizer  - threads                : 10
# (CVXPY) Jan 27 02:42:23 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Jan 27 02:42:23 PM: Optimizer  - Constraints            : 400
# (CVXPY) Jan 27 02:42:23 PM: Optimizer  - Cones                  : 2501
# (CVXPY) Jan 27 02:42:23 PM: Optimizer  - Scalar variables       : 7902              conic                  : 7502
# (CVXPY) Jan 27 02:42:23 PM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Jan 27 02:42:23 PM: Factor     - setup time             : 0.40
# (CVXPY) Jan 27 02:42:23 PM: Factor     - dense det. time        : 0.01              GP order time          : 0.00
# (CVXPY) Jan 27 02:42:23 PM: Factor     - nonzeros before factor : 8.02e+04          after factor           : 8.02e+04
# (CVXPY) Jan 27 02:42:23 PM: Factor     - dense dim.             : 0                 flops                  : 8.20e+08
# (CVXPY) Jan 27 02:42:23 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Jan 27 02:42:23 PM: 0   5.0e+02  1.3e+00  4.1e+03  0.00e+00   -2.069595998e+03  2.012755004e+03   1.0e+00  1.03
# (CVXPY) Jan 27 02:42:23 PM: 1   2.8e+02  7.2e-01  2.1e+03  2.17e-01   -2.567327492e+03  4.032335266e+02   5.6e-01  1.31
# (CVXPY) Jan 27 02:42:23 PM: 2   1.6e+02  4.1e-01  1.1e+03  2.24e-01   -3.039523459e+03  -8.374436034e+02  3.2e-01  1.33
# (CVXPY) Jan 27 02:42:23 PM: 3   1.2e+02  3.1e-01  8.4e+02  2.17e-01   -3.123291877e+03  -1.209201010e+03  2.4e-01  1.34
# (CVXPY) Jan 27 02:42:23 PM: 4   1.1e+02  2.8e-01  7.5e+02  2.10e-01   -3.066791227e+03  -1.249679909e+03  2.2e-01  1.36
# (CVXPY) Jan 27 02:42:23 PM: 5   7.2e+01  1.9e-01  4.8e+02  1.98e-01   -2.745128514e+03  -1.281868645e+03  1.4e-01  1.37
# (CVXPY) Jan 27 02:42:23 PM: 6   4.2e+01  1.1e-01  2.7e+02  1.81e-01   -2.152435500e+03  -1.055992219e+03  8.4e-02  1.39
# (CVXPY) Jan 27 02:42:23 PM: 7   2.6e+01  6.7e-02  1.6e+02  1.65e-01   -1.557637370e+03  -7.091000690e+02  5.2e-02  1.40
# (CVXPY) Jan 27 02:42:23 PM: 8   7.2e+00  1.8e-02  3.9e+01  1.61e-01   -1.428838750e+02  2.371480752e+02   1.4e-02  1.42
# (CVXPY) Jan 27 02:42:23 PM: 28  5.1e-04  1.3e-06  1.6e-04  9.47e-01   3.134357148e+03   3.134533771e+03   1.0e-06  1.77
# (CVXPY) Jan 27 02:42:23 PM: 29  3.8e-04  9.9e-07  1.1e-04  9.05e-01   3.135534737e+03   3.135670357e+03   7.6e-07  1.79
# (CVXPY) Jan 27 02:42:23 PM: 30  3.3e-04  8.5e-07  8.7e-05  9.16e-01   3.136035393e+03   3.136152627e+03   6.6e-07  1.81
# (CVXPY) Jan 27 02:42:23 PM: 31  1.6e-04  4.0e-07  2.9e-05  9.28e-01   3.137685734e+03   3.137742051e+03   3.1e-07  1.82
# (CVXPY) Jan 27 02:42:24 PM: 32  2.1e-05  5.3e-08  1.5e-06  9.68e-01   3.139005767e+03   3.139013330e+03   4.1e-08  1.83
# (CVXPY) Jan 27 02:42:24 PM: 33  1.3e-06  3.2e-09  2.3e-08  9.97e-01   3.139206570e+03   3.139207030e+03   2.5e-09  1.85
# (CVXPY) Jan 27 02:42:24 PM: 34  4.0e-07  1.3e-10  1.7e-10  1.00e+00   3.139219056e+03   3.139219074e+03   9.7e-11  1.87
# (CVXPY) Jan 27 02:42:24 PM: 35  1.3e-08  4.1e-12  1.0e-12  1.00e+00   3.139219548e+03   3.139219548e+03   3.2e-12  1.90
# (CVXPY) Jan 27 02:42:24 PM: Optimizer terminated. Time: 1.97
# (CVXPY) Jan 27 02:42:24 PM:
# (CVXPY) Jan 27 02:42:24 PM:
# (CVXPY) Jan 27 02:42:24 PM: Interior-point solution summary
# (CVXPY) Jan 27 02:42:24 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Jan 27 02:42:24 PM:   Solution status : OPTIMAL
# (CVXPY) Jan 27 02:42:24 PM:   Primal.  obj: 3.1392195479e+03    nrm: 3e+03    Viol.  con: 6e-07    var: 0e+00    cones: 0e+00
# (CVXPY) Jan 27 02:42:24 PM:   Dual.    obj: 3.1392195485e+03    nrm: 6e+00    Viol.  con: 0e+00    var: 5e-10    cones: 0e+00
# (CVXPY) Jan 27 02:42:24 PM: Problem status: optimal
# (CVXPY) Jan 27 02:42:24 PM: Optimal value: -3.139e+03
# (CVXPY) Jan 27 02:42:24 PM: Compilation took 2.701e-01 seconds
# (CVXPY) Jan 27 02:42:24 PM: Solver (including time spent in interface) took 2.363e+00 seconds
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# done.
# Running EM: done.

# %%
est_g = eb_model_g.atoms
est_g_weights = eb_model_g.weights

# %% [markdown]
# ## Plotting

# %%
plt.rcParams.update({'font.size': 22, 'mathtext.fontset': 'stix', 'font.family': 'serif', 'font.serif': 'Palatino'})
fig, ax = plt.subplots(3, 4, sharex=True, sharey=True, figsize=(20,16))
Z_alpha = 0.75
Z_s = 1.0
H_s = 100
G_alpha = 0.5

ax[0,0].set_title(r'$H$ (Prior for $\mu$)')
ax[0,0].scatter(centers[:,0], centers[:,1], s=H_s,color='blue', alpha=Z_alpha)

ax[0,1].set_title(r'$G$ (Prior for $\Theta$)')
ax[0,1].scatter(Theta[:,0], Theta[:,1], s=Z_s,color='black', alpha=Z_alpha)

ax[0,2].set_title(r'$\delta_{\mathcal{B}}(Z) = \mathbb{E}[\Theta | Z]$')
ax[0,2].scatter(ob_means[:,0], ob_means[:,1], s=Z_s,color='black', alpha=Z_alpha)

ax[0,3].set_title(r'Oracle Mixture Posterior')
ax[0,3].scatter(ob_samples[:,0], ob_samples[:,1], s=Z_s,color='black', alpha=Z_alpha)

ax[1,0].set_title(r'$\hat{H}$ (Estimated Prior for $\mu$)')
ax[1,0].scatter(eb_model_h.atoms[:,0], eb_model_h.atoms[:,1], s=eb_model_h.weights*H_s,color='black', alpha=Z_alpha)

ax[1,1].set_title(r'$\hat{G}(\hat{H})$')
ax[1,1].scatter(g_hat_samples[:,0], g_hat_samples[:,1], s=Z_s,color='black', alpha=Z_alpha)

ax[1,2].set_title(r'$\int \mathbb{E}[\Theta|Z, \mu] d\hat{H}(\mu | Z)$')
ax[1,2].scatter(post_theta_means[:,0], post_theta_means[:,1], s=Z_s,color='black', alpha=Z_alpha)

ax[1,3].set_title(r'Samples from $\int p(\Theta|Z, \mu) d\hat{H}(\mu | Z)$')
ax[1,3].scatter(post_theta_samples[:,0], post_theta_samples[:,1], s=Z_s,color='black', alpha=Z_alpha)

ax[2,0].set_title(r'$Z$')
ax[2,0].scatter(Z[:,0], Z[:,1], s=Z_s,color='black', alpha=Z_alpha)

ax[2,1].set_title(r'$\hat{G}$')
ax[2,1].scatter(est_g[:,0], est_g[:,1], s=est_g_weights*H_s,color='black', alpha=Z_alpha)

ax[2,2].set_title(r'$\hat{\delta}_{\mathcal{B}}(Z) = \int \Theta d\hat{G}(\Theta | Z)$')
ax[2,2].scatter(eb_means_g[:,0], eb_means_g[:,1], s=Z_s,color='black', alpha=Z_alpha)

ax[2,3].set_title(r'Samples from $\hat{G} \mid Z$')
ax[2,3].scatter(g_samples[:,0] + 0.02*np.random.randn(g_samples.shape[0]), g_samples[:,1] + 0.02*np.random.randn(g_samples.shape[0]), s=Z_s,color='black', alpha=Z_alpha)


u = np.linspace(0,2*np.pi)
circ1 = center1 + 2*np.sqrt(tau2)*np.vstack([np.sin(u),np.cos(u)]).T
circ2 = center2 + 2*np.sqrt(tau2)*np.vstack([np.sin(u),np.cos(u)]).T
for i in range(3):
    for j in range(4):
        # if i > 0 or j > 0:
        ax[i,j].plot(circ1[:,0],circ1[:,1],color='blue',linestyle='dashed', alpha=0.75)
        ax[i,j].plot(circ2[:,0],circ2[:,1],color='blue',linestyle='dashed', alpha=0.75)
            # ax[i,j].scatter(Theta[:,0], Theta[:,1], s=Z_s,color='blue', alpha=G_alpha)

plt.xlim([-1.25,1.25])
plt.ylim([-1.25, 1.25])
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 24
#      21 ax[1,0].scatter(eb_model_h.atoms[:,0], eb_model_h.atoms[:,1], s=eb_model_h.weights*H_s,color='black', alpha=Z_alpha)
#      23 ax[1,1].set_title(r'$\hat{G}(\hat{H})$')
# ---> 24 ax[1,1].scatter(g_hat_samples[:,0], g_hat_samples[:,1], s=Z_s,color='black', alpha=Z_alpha)
#      26 ax[1,2].set_title(r'$\int \mathbb{E}[\Theta|Z, \mu] d\hat{H}(\mu | Z)$')
#      27 ax[1,2].scatter(post_theta_means[:,0], post_theta_means[:,1], s=Z_s,color='black', alpha=Z_alpha)
#
# NameError: name 'g_hat_samples' is not defined
